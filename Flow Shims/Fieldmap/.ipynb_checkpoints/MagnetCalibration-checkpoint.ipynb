# %%
import mrc #All functionality for the MRC is included in this library
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sg 
import time

# mrr = mrc.Console(frequency=22.05e6)              # Connect to the MRR and initialize the system
mrr = mrc.Console(frequency=8.05e6)      # Connect to the MRR and initialize the system
# Out:
# Connected to COM3

# %%
# %matplotlib widget
sos = sg.butter(20, 5e3, 'low', fs=100e3, output='sos')

# %% [markdown]
# ## SE On CAS Magnet

# %%
mrr.amp(3)
# mrr.freq(8.06e6)
mrr.freq(8.06e6) # probe reading is 1911
mrr.run(mrc.build_spinecho(5e-3, 100e-6, 150e-6))
rx_data1 = sg.sosfiltfilt(sos, mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2)))
# rx_data1 = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))

cpmg_fig = plt.figure(figsize=(9,5))                                      # Plot the results
# plt.plot(np.real(rx_data1))
# plt.plot(np.imag(rx_data1))
plt.plot(np.real(mrr.rx_data))
plt.plot(np.imag(mrr.rx_data))
# plt.ylim([-15000,15000])
# plt.xlim([0,2000])
plt.title("Gd Doped Water Sample")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
# plt.legend(["$T_2$ = %0.2f" % (mrc.get_t2(echo_amplitudes, 3e-3))]) # Put the calculated T2 in the legend
plt.show()
# Out:
# Setting Coil Strength to 3 Counts/Hz
# Setting Frequency to 8060000.0
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 3008
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Run on Medium Magnet and MM Probe

# %%
mrr.amp(7)
# mrr.freq(8.06e6)
mrr.freq(8.1e6) # probe reading is 1866. Grounding magnet to probe is very good for noise
mrr.run(mrc.build_spinecho(8e-3, 150e-6, 150e-6))
rx_data1 = sg.sosfiltfilt(sos, mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2)))
# rx_data1 = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))

cpmg_fig, ax = plt.subplots(2,1,figsize=(9,5))                                      # Plot the results
# plt.plot(np.real(rx_data1))
# plt.plot(np.imag(rx_data1))
ax[0].plot(np.real(mrr.rx_data))
ax[0].plot(np.imag(mrr.rx_data))

ft = np.fft.fft(np.fft.fftshift(mrr.rx_data[700:1100]))
fs = np.fft.fftfreq(len(ft), d=1/100e3)
ax[1].plot(np.fft.fftshift(fs), np.real(np.fft.fftshift(ft)))
ax[1].plot(np.fft.fftshift(fs), np.imag(np.fft.fftshift(ft)))
ax[1].plot(np.fft.fftshift(fs), np.abs(np.fft.fftshift(ft)))
ax[1].set_xlim([-10000,10000])
# plt.ylim([-15000,15000])
# plt.xlim([0,2000])
plt.title("Gd Doped Water Sample")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
# plt.legend(["$T_2$ = %0.2f" % (mrc.get_t2(echo_amplitudes, 3e-3))]) # Put the calculated T2 in the legend
plt.show()
# Out:
# Setting Coil Strength to 7 Counts/Hz
# Setting Frequency to 8100000.0
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 4800
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.save("grad385.npy", mrr.rx_data)

# %%
mrr.amp(3)
t_echo = 2e-3
num_echoes = 400
onlystatic = True
t90 = 150e-6
t180 = 150e-6

mrr.run_cpmg(num_echoes, t_echo, t90, t180)
echo_times = np.arange(0, t_echo * num_echoes, t_echo)
mrr.rx_data = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))
filtdata = sg.sosfiltfilt(sos, mrr.rx_data)
static_echo_amplitudes = mrc.get_echo_amplitudes(filtdata, num_echoes, t_echo, t90, use_real=False)
mrr.run(mrc.build_spinecho(3e-3, 150e-6, 150e-6))
if not onlystatic:
    time.sleep(15)
    echo_times, forward_echo_amplitudes = mrr.run_cpmg(num_echoes, t_echo, t90, t180)
    mrr.run(mrc.build_spinecho(3e-3, t90, t180))
    time.sleep(15)
    echo_times, reverse_echo_amplitudes = mrr.run_cpmg(num_echoes, t_echo, t90, t180)
    # mrr.run(mrc.build_spinecho(3e-3, 300e-6, 300e-6))

cpmg_fig = plt.figure(figsize=(9,5))                                      # Plot the results
# plt.plot(echo_times, echo_amplitudes, color='violet')
plt.plot(echo_times, static_echo_amplitudes, color='violet')
if not onlystatic:
    plt.plot(echo_times, forward_echo_amplitudes, color='purple')
    plt.plot(echo_times, reverse_echo_amplitudes, color='blueviolet')
plt.title("Flow Probe 12ml/min")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
if(onlystatic):
    plt.legend(["Static $T_2$ = %0.4f" % (mrc.get_t2(static_echo_amplitudes[50:], t_echo))])
else:
    plt.legend(["Static $T_2$ = %0.2f" % (mrc.get_t2(static_echo_amplitudes, t_echo)),
                "Forward $T_2$ = %0.2f" % (mrc.get_t2(forward_echo_amplitudes, t_echo)),
                "Reverse $T_2$ = %0.2f" % (mrc.get_t2(reverse_echo_amplitudes, t_echo))]) # Put the calculated T2 in the legend
# plt.ylim([-500, 30000])
plt.show()
# Out:
# Setting Coil Strength to 3 Counts/Hz
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 32
#      30 plt.ylabel("Amplitude")
#      31 if(onlystatic):
# ---> 32     plt.legend(["Static $T_2$ = %0.4f" % (mrc.get_t2(static_echo_amplitudes[50:], t_echo))])
#      33 else:
#      34     plt.legend(["Static $T_2$ = %0.2f" % (mrc.get_t2(static_echo_amplitudes, t_echo)),
#      35                 "Forward $T_2$ = %0.2f" % (mrc.get_t2(forward_echo_amplitudes, t_echo)),
#      36                 "Reverse $T_2$ = %0.2f" % (mrc.get_t2(reverse_echo_amplitudes, t_echo))]) # Put the calculated T2 in the legend
#
# File ~\MR-Core\software\mrc\mrc\rx_processing.py:22, in get_t2(echo_data, te)
#      20 def _decay(x, a, b, c):
#      21     return a * np.exp(-b * x)+c
# ---> 22 popt, _ = opt.curve_fit(_decay, np.arange(len(echo_data))*te, echo_data/np.max(echo_data))
#      23 return 1/popt[1]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1012, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1010     cost = np.sum(infodict['fvec'] ** 2)
#    1011     if ier not in [1, 2, 3, 4]:
# -> 1012         raise RuntimeError("Optimal parameters not found: " + errmsg)
#    1013 else:
#    1014     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#    1015     if 'max_nfev' not in kwargs:
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 800.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.save("05_ccw_2.npy", mrr.rx_data, allow_pickle=True)

# %% [markdown]
# # Process Monitoring

# %%
from pump import *
peri = Pump()
time.sleep(1)
import datetime
peri.setspeed(2, 30)
time.sleep(2)
peri.setdir(2, 'ccw')

# %%
# peri.stop(1)
# peri= None
# peri.setdir(2, 'ccw')
peri.start(2)
ft2s = np.empty(0)
bt2s = np.empty(0)
st2s = np.empty(0)

# %%
numeach = 80
for i in range(5*numeach):
    
    if(i < numeach):
        print("speed 80")
        peri.setspeed(2, 80)
        time.sleep(1)
        peri.setspeed(2, 80)
        peri.start(2)
    elif (i < 2*numeach):
        print("speed 10")
        peri.setspeed(2,10)
        time.sleep(1)
        peri.setspeed(2, 10)
        peri.start(2)
    elif (i < 3*numeach):
        print("speed 50")
        peri.setspeed(2,50)
        time.sleep(1)
        peri.setspeed(2, 50)
        peri.start(2)
    elif (i < 4*numeach):
        print("speed 80")
        peri.setspeed(2,30)
        time.sleep(1)
        peri.setspeed(2, 30)
        peri.start(2)
    else:
        print("speed 0")
        peri.setspeed(2,0)
        time.sleep(1)
        peri.setspeed(2, 0)
        peri.start(2)
        
    time.sleep(6)

            
    try:
        # take a flow measurement
        mrr.run_cpmg(num_echoes, t_echo, t90, t180)
        echo_times = np.arange(0, t_echo * num_echoes, t_echo)
        mrr.rx_data = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))
        filtdata = sg.sosfiltfilt(sos, mrr.rx_data)
        np.save(("Data/flow_cpmg" + datetime.datetime.now().isoformat() + ".npy").replace(':','-'), mrr.rx_data, allow_pickle=True)
        static_echo_amplitudes = mrc.get_echo_amplitudes(filtdata, num_echoes, t_echo, t90, use_real=False)
        mrr.run(mrc.build_spinecho(3e-3, 300e-6, 300e-6))
        t2 = mrc.get_t2(static_echo_amplitudes, t_echo)
        ft2s = np.append(ft2s, t2)
        print("Flow T2: %0.4f" % (t2))

        # Stop the pump
        peri.stop(2)
        time.sleep(6)

        # take a static measurement
        mrr.run_cpmg(num_echoes, t_echo, t90, t180)
        echo_times = np.arange(0, t_echo * num_echoes, t_echo)
        mrr.rx_data = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))
        filtdata = sg.sosfiltfilt(sos, mrr.rx_data)
        np.save(("Data/stop_cpmg" + datetime.datetime.now().isoformat() + ".npy").replace(':','-'), mrr.rx_data, allow_pickle=True)
        static_echo_amplitudes = mrc.get_echo_amplitudes(filtdata, num_echoes, t_echo, t90, use_real=False)
        mrr.run(mrc.build_spinecho(3e-3, 300e-6, 300e-6))
        t2 = mrc.get_t2(static_echo_amplitudes, t_echo)
        st2s = np.append(st2s, t2)
        print("Static T2: %0.4f" % (t2))
        
        # Reverse the pump
        peri.setdir(2, 'cw')
        time.sleep(1)
        peri.start(2)
        time.sleep(4)
    
        # take a reverse flow measurement
        mrr.run_cpmg(num_echoes, t_echo, t90, t180)
        echo_times = np.arange(0, t_echo * num_echoes, t_echo)
        mrr.rx_data = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))
        filtdata = sg.sosfiltfilt(sos, mrr.rx_data)
        np.save(("Data/back_cpmg" + datetime.datetime.now().isoformat() + ".npy").replace(':','-'), mrr.rx_data, allow_pickle=True)
        static_echo_amplitudes = mrc.get_echo_amplitudes(filtdata, num_echoes, t_echo, t90, use_real=False)
        mrr.run(mrc.build_spinecho(3e-3, 300e-6, 300e-6))
        t2 = mrc.get_t2(static_echo_amplitudes, t_echo)
        bt2s = np.append(bt2s, t2)
        print("Back T2: %0.4f" % (t2))
    
        # Correct the pump
        peri.setdir(2, 'ccw')
        time.sleep(5)
        print(i)

    except Exception as e:
        print("Sample Failed")
        print(e)
        plt.plot(static_echo_amplitudes)
        plt.show()
# Out:
# speed 80
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 6
#       4 if(i < numeach):
#       5     print("speed 80")
# ----> 6     peri.setspeed(2, 80)
#       7     time.sleep(1)
#       8     peri.setspeed(2, 80)
#
# NameError: name 'peri' is not defined

# %% [markdown]
# ## Bioreactor Monitoring

# %%
ft2s = np.empty(0)
# from pump import *
# peri = Pump()
# time.sleep(1)
# peri.setspeed(2, 4)

# %%
import datetime
numsamples = 4000
sample_period = 30
for i in range(numsamples):
    try:
        # if(i % 60 == 0):
        #     print("purging")
        #     peri.setspeed(2, 100)
        #     time.sleep(120)
        #     peri.setspeed(2, 4)
        # take a flow measurement
        mrr.run_cpmg(num_echoes, t_echo, t90, t180)
        echo_times = np.arange(0, t_echo * num_echoes, t_echo)
        mrr.rx_data = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))
        filtdata = sg.sosfiltfilt(sos, mrr.rx_data)
        np.save(("Dairy_Data_3/flow_cpmg" + datetime.datetime.now().isoformat() + ".npy").replace(':','-'), mrr.rx_data, allow_pickle=True)
        static_echo_amplitudes = mrc.get_echo_amplitudes(filtdata, num_echoes, t_echo, t90, use_real=False)
        mrr.run(mrc.build_spinecho(3e-3, 150e-6, 150e-6))
        t2 = mrc.get_t2(static_echo_amplitudes[1:], t_echo)
        ft2s = np.append(ft2s, t2)
        print("Flow T2: %0.4f" % (t2))
        time.sleep(sample_period)

    except Exception as e:
        print("Sample Failed")
        print(e)
        plt.plot(static_echo_amplitudes)
        plt.show()
        time.sleep(sample_period)
# Out:
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1178
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1172
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1177
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1182
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1177
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1172
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1183
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1180
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1220
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1174
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1187
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1164
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1174
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1197
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1193
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1186
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1201
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1197
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1178
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1219
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1186
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1207
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1191
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1226
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1197
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1178
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1198
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1155
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1205
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1213
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1211
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1227
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1211
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1180
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1180
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1220
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1189
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1200
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1213
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1197
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1202
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1177
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1190
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1200
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1179
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1183
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1208
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1179
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1191
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1168
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1222
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1202
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1210
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1201
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1194
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1182
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1202
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1230
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1158
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1197
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1183
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1207
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1180
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1186
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1183
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1203
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1204
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1191
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1195
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1195
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1188
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1187
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1225
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1205
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1205
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1188
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1175
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1198
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1196
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1206
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1180
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1181
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1187
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1185
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1174
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1201
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1205
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1180
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1178
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1193
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1160
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1203
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1169
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1182
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1166
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1166
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1176
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1162
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1197
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1166
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1203
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1236
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1235
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1229
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1183
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1237
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1243
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1267
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1271
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1298
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1321
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1293
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1344
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1311
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1339
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1335
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1347
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1376
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1414
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1390
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1421
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1447
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1440
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1403
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1466
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1500
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1481
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1516
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1496
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1518
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1522
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1561
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1544
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1587
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1589
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1572
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1589
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1603
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1649
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1629
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1662
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1709
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1701
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1695
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1709
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1742
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1708
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1729
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1776
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1757
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1772
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1830
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1802
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1806
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1819
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1828
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1808
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1856
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1872
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1886
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1883
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1891
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1896
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1936
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1939
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1970
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1944
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1988
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2000
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2008
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.1996
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2014
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2052
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2074
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2057
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2092
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2093
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2066
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2138
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2112
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2138
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2168
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2175
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2160
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2162
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2079
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2198
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2252
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2292
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2270
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2265
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2273
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2313
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2352
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2282
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2358
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2321
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2318
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2284
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2401
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2304
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2333
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2258
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2321
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2303
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2292
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2374
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2314
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2283
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2316
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2314
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2337
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2307
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2331
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2326
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2325
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2296
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2332
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2298
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2371
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2365
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2303
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2308
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2292
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2334
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2326
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2339
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2349
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2324
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2316
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2317
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2336
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2332
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2353
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2294
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2292
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2326
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2320
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2334
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2329
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2329
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2303
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2280
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2325
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2387
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2293
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2325
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2307
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2313
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2315
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2364
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2311
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2246
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2366
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2365
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2366
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2300
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2289
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2315
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2250
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2364
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2320
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2306
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2259
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2225
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2295
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2319
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2357
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2325
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2313
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2305
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2344
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2283
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2299
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2328
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2326
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2254
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2298
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2282
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2301
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2327
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2330
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 320448
#
# Loading Sequence... Done.
# Running Sequence
# Received Bytes: 1856
#
# Flow T2: 0.2286
# Loading Sequence...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 12
#       4 for i in range(numsamples):
#       5     try:
#       6         # if(i % 60 == 0):
#       7         #     print("purging")
#    (...)
#      10         #     peri.setspeed(2, 4)
#      11         # take a flow measurement
# ---> 12         mrr.run_cpmg(num_echoes, t_echo, t90, t180)
#      13         echo_times = np.arange(0, t_echo * num_echoes, t_echo)
#      14         mrr.rx_data = mrr.rx_data * np.exp(-1j*(np.angle(mrr.rx_data[19]) + np.pi/2))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mrc\Console.py:158, in Console.run_cpmg(self, n_echoes, echo_time, t90, t180)
#     157 def run_cpmg(self, n_echoes = 100, echo_time = 3e-3, t90 = 200e-6, t180 = 200e-6):
# --> 158     self.load(build_cpmg(echo_time, n_echoes, t90, t180))
#     159     self.run()
#     160     return np.arange(0, echo_time * n_echoes, echo_time), get_echo_amplitudes(self.rx_data, n_echoes, echo_time, t90)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mrc\Console.py:103, in Console.load(self, sequence)
#     101 for i in range(int(file_size/64)):
#     102     self.ser.write(byte_array[64*i:64*i+64])
# --> 103     time.sleep(0.01)
#     104 if file_size - int(file_size/64)*64 > 0:
#     105     self.ser.write(byte_array[64*int(file_size/64):])
#
# KeyboardInterrupt:
